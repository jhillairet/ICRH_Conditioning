# %%
import ICRH_FastData as fastacq 
import ICRH_FileIO as io
import matplotlib.pylab as plt
# %matplotlib notebook

# %%
# Returns the list of all the files located in the Fast Data directory
file_list = io.list_local_files(local_data_path='data/Fast_Data')
# Then deduces the shot numbers represented by those files
fastacq.get_shot_list(file_list)
# Out:
# [80, 79, 78, 77, 60, 59, 58, 57, 55, 53, 52, 51, 50]

# %%
# generate a data structure containing all the fast data of a shot
shot = 80

fd = fastacq.FastData(shot)

fd.Q1_amplitude.head()
# Out:
#           V1  V2  V3  V4   PiG   PrG   PiD   PrD  CGB  CDH  CDB
# CGH
# 41502705  11  11  11  11  7238  7277  7264  7261  NaN  NaN  NaN NaN
# 41502715  11  11  11  11  7158  7197  7182  7188  NaN  NaN  NaN NaN
# 41502725  11  11  11  11  7232  7267  7256  7253  NaN  NaN  NaN NaN
# 41502735  11  11  11  11  7168  7204  7189  7194  NaN  NaN  NaN NaN
# 41502745  11  11  11  11  7189  7228  7217  7220  NaN  NaN  NaN NaN

# %%
fig,ax = plt.subplots(3,2, sharex=True)
fd.Q1_amplitude['PiG'].plot(ax=ax[0,0])
fd.Q1_amplitude['PiD'].plot(ax=ax[0,0])
fd.Q2_amplitude['PiG'].plot(ax=ax[1,0])
fd.Q2_amplitude['PiD'].plot(ax=ax[1,0])
fd.Q4_amplitude['PiG'].plot(ax=ax[2,0])
fd.Q4_amplitude['PiD'].plot(ax=ax[2,0])
# Out:
# <img src="data:image/png;base64,..." width="639.8333142648146">

# %%
fd.Q1_amplitude['PiG'].index
# Out:
# Int64Index([41502705, 41502715, 41502725, 41502735, 41502745, 41502755,
#             41502765, 41502775, 41502785, 41502795,
#             ...
#             43002605, 43002615, 43002625, 43002635, 43002645, 43002655,
#             43002665, 43002675, 43002685, 43002695],
#            dtype='int64', name='CGH', length=150000)
